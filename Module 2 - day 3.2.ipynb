# %%
# Lasso and Ridge - L1 and L2 regularization

# %%
import pandas as pd
from sklearn.linear_model import Lasso, Ridge, LinearRegression
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("Car_sales.csv")

# %%
df.dropna(inplace=True)

# %%
X = df[['Horsepower','Wheelbase', 'Width', 'Length']]

# %%
y = df["Price_in_thousands"]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.2, random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
lasso_model = Lasso(alpha=1)
lasso_model.fit(X_train,y_train)
# Out:
# Lasso(alpha=1)

# %%
lasso_model.score(X_test,y_test)
# Out:
# 0.8398149810736024

# %%
lasso_model.coef_
# Out:
# array([12.31753042, -0.        , -0.14363363, -1.06389512])

# %%
linear_model = LinearRegression()
linear_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
linear_model.score(X_test,y_test)
# Out:
# 0.8015500794904071

# %%
linear_model.coef_
# Out:
# array([14.51348994,  1.52095034, -2.0280925 , -2.69958048])

# %%
ridge_model = Ridge(alpha=10)
ridge_model.fit(X_train,y_train)
# Out:
# Ridge(alpha=10)

# %%
ridge_model.score(X_test,y_test)
# Out:
# 0.8388306388342053

# %%
ridge_model.coef_
# Out:
# array([12.42501284, -0.07981022, -0.81746863, -1.38475705])
