# %%
import numpy as np
import pandas as pd

# %%
# dir(np)

# %%
alist = [10,20,30,40,50]

# %%
alist + alist
# Out:
# [10, 20, 30, 40, 50, 10, 20, 30, 40, 50]

# %%
np_a = np.array(alist)
np_a
# Out:
# array([10, 20, 30, 40, 50])

# %%
type(np_a)
# Out:
# numpy.ndarray

# %%
np_a + 5
# Out:
# array([15, 25, 35, 45, 55])

# %%
np_a + np_a
# Out:
# array([ 20,  40,  60,  80, 100])

# %%
np_a[0] = 100.99

# %%
np_a
# Out:
# array([100,  20,  30,  40,  50])

# %%
blist = [[10,20,30],[40,50,60],[70,80,90]]
blist
# Out:
# [[10, 20, 30], [40, 50, 60], [70, 80, 90]]

# %%
np_2 = np.array(blist)

# %%
np_2
# Out:
# array([[10, 20, 30],
#        [40, 50, 60],
#        [70, 80, 90]])

# %%
np_2.ndim
# Out:
# 2

# %%
np_a.ndim
# Out:
# 1

# %%
np_2.shape
# Out:
# (3, 3)

# %%
type(np_2)
# Out:
# numpy.ndarray

# %%
np_2.dtype
# Out:
# dtype('int64')

# %%
np_2.size
# Out:
# 9

# %%
np_2.itemsize
# Out:
# 8

# %%
np_2.nbytes
# Out:
# 72

# %%
np_2
# Out:
# array([[10, 20, 30],
#        [40, 50, 60],
#        [70, 80, 90]])

# %%
# [start : stop , start : stop]

# %%
np_2[0:2,  1:]
# Out:
# array([[20, 30],
#        [50, 60]])

# %%
np_2[1:2, 0:2]
# Out:
# array([[40, 50]])

# %%
np_2
# Out:
# array([[10, 20, 30],
#        [40, 50, 60],
#        [70, 80, 90]])

# %%
new = np_2.copy()

# %%
new[0,0] = 1000

# %%
np_2
# Out:
# array([[100,  20,  30],
#        [ 40,  50,  60],
#        [ 70,  80,  90]])

# %%
np_a
sum(np_a)
# Out:
# 240

# %%
big_array = np.random.rand(1000000)
# %timeit sum(big_array)
# Out:
# 37.3 ms ± 3.22 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
big_array = np.random.rand(1000000)
# %timeit np.sum(big_array)
# Out:
# 197 µs ± 12.1 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
sum(np_2)
# Out:
# array([210, 150, 180])

# %%
np.sum(np_2)
# Out:
# 540

# %%
np_2.sum()
# Out:
# 540

# %%
np_2.max()
# Out:
# 100

# %%
alist
# Out:
# [10, 20, 30, 40, 50]

# %%
s = pd.Series(alist)
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s.values
# Out:
# array([10, 20, 30, 40, 50])

# %%
# s[0] = 100.99

# %%
s + 5
# Out:
# 0    105.99
# 1     25.00
# 2     35.00
# 3     45.00
# 4     55.00
# dtype: float64

# %%
s + s
# Out:
# 0    201.98
# 1     40.00
# 2     60.00
# 3     80.00
# 4    100.00
# dtype: float64

# %%
s.ndim
# Out:
# 1

# %%
s.shape
# Out:
# (5,)

# %%
s.dtype
# Out:
# dtype('float64')

# %%
df = pd.DataFrame()

# %%
# help(pd.DataFrame)

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df["Stock"] = ["MSFT","AAPL","IBM","ORCL"]

# %%
df["Price"] = [260.99, 210.00, 115.00, 56.00]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.columns
# Out:
# Index(['Stock', 'Price'], dtype='object')

# %%
df.values
# Out:
# array([['MSFT', 260.99],
#        ['AAPL', 210.0],
#        ['IBM', 115.0],
#        ['ORCL', 56.0]], dtype=object)

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (4, 2)

# %%
df.dtypes
# Out:
# Stock     object
# Price    float64
# dtype: object

# %%
df["Stock"]
# Out:
# 0    MSFT
# 1    AAPL
# 2     IBM
# 3    ORCL
# Name: Stock, dtype: object

# %%
df["Price"]
# Out:
# 0    260.99
# 1    210.00
# 2    115.00
# 3     56.00
# Name: Price, dtype: float64

# %%
a = ["Price", "Amnt"]
df[["Amnt","Price"]]
# Out:
#        Amnt   Price
# Stock
# MSFT    100  260.99
# AAPL    200  210.00
# IBM     300  115.00
# ORCL    400   56.00

# %%
df["Amnt"] = [100, 200,300,400]

# %%
df["Total"] = df["Price"] * df["Amnt"]

# %%
df.index = df["Stock"]

# %%
df.drop("Stock", axis=1, inplace=True)

# %%
df
# Out:
#         Price  Amnt    Total
# Stock
# MSFT   260.99   100  26099.0
# AAPL   210.00   200  42000.0
# IBM    115.00   300  34500.0
# ORCL    56.00   400  22400.0

# %%
# loc vs iloc
# loc - labels
# iloc - index loc

# %%
df.loc["AAPL":"IBM", "Amnt":"Total"]
# Out:
#        Amnt    Total
# Stock
# AAPL    200  42000.0
# IBM     300  34500.0

# %%
df[["Amnt","Total"]].loc["AAPL":"IBM"]
# Out:
#        Amnt    Total
# Stock
# AAPL    200  42000.0
# IBM     300  34500.0

# %%
df.iloc[1:3, 1:]
# Out:
#        Amnt    Total
# Stock
# AAPL    200  42000.0
# IBM     300  34500.0

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#   Stock   Price  Amnt    Total
# 0  MSFT  260.99   100  26099.0
# 1  AAPL  210.00   200  42000.0
# 2   IBM  115.00   300  34500.0
# 3  ORCL   56.00   400  22400.0

# %%
condition = df["Price"] < 100
df[condition]
# Out:
#   Stock  Price  Amnt    Total
# 3  ORCL   56.0   400  22400.0

# %%
df[ df["Price"] < 100 ]
# Out:
#   Stock  Price  Amnt    Total
# 3  ORCL   56.0   400  22400.0

# %%
max_total = df["Total"].max()
max_total_condition = df["Total"] == max_total
df[max_total_condition][["Stock","Total"]]
# Out:
#   Stock    Total
# 1  AAPL  42000.0

# %%
df[df["Total"]==df["Total"].max()]
# Out:
#   Stock  Price  Amnt    Total
# 1  AAPL  210.0   200  42000.0

# %%
# find stock with lowest amount of shares
min_amnt = df["Amnt"].min()
min_total_condition = df["Amnt"] == min_amnt
df[min_total_condition][["Stock", "Amnt"]]
# Out:
#   Stock  Amnt
# 0  MSFT   100
