# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
# Out:
# /Users/art/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv("carprices.csv")

# %%
df.columns
# Out:
# Index(['Mileage', 'Age(yrs)', 'Sell Price($)'], dtype='object')

# %%
df.rename(columns={'Age(yrs)':"Age", 'Sell Price($)':"Price"}, inplace=True)

# %%
plt.scatter(df["Age"],df["Price"])
plt.xlabel("Age")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
sns.pairplot(df)
# Out:
# /Users/art/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/art/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/art/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df.shape
# Out:
# (20, 3)

# %%
X = df.drop("Price", axis=1)
y = df["Price"]

# %%
X_train,X_test, y_train, y_test = train_test_split(X,y, test_size=.2, 
                                                   random_state=5)

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test,y_test)
# Out:
# 0.690923805944647

# %%
df_predicted = pd.DataFrame()

# %%
df_predicted["Predicted"] = model.predict(X_test)

# %%
df_predicted["Actual"] = y_test.values

# %%
X_test.reset_index(drop=True, inplace=True)

# %%
pd.concat([X_test,df_predicted],axis=1)
# Out:
#    Mileage  Age     Predicted  Actual
# 0    57000    5  26172.697561   26100
# 1    59000    5  25656.165580   26750
# 2    69000    5  23073.505675   19700
# 3    52000    5  27464.027513   28200
