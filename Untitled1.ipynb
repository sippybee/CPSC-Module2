# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
alist = ["orange","banana","orange","banana"]

# %%
le = LabelEncoder()

# %%
le.fit_transform(alist)
# Out:
# array([1, 0, 1, 0])

# %%
df = pd.DataFrame()

# %%
df["Fruit"] = alist

# %%
pd.concat([pd.get_dummies(df["Fruit"], dtype=int), df],axis=1)
# Out:
#    banana  orange   Fruit
# 0       0       1  orange
# 1       1       0  banana
# 2       0       1  orange
# 3       1       0  banana

# %%
string = "a1b2c3d4e5"
sum([int(x) for x in string if x.isdigit()])
# Out:
# 15

# %%
# "abcde"
non_digits = ''.join([char for char in string if not char.isdigit()])
print(non_digits)
# Out:
# abcde

# %%
''.join([char for char in string if char.isalpha()])
# Out:
# 'abcde'

# %%
word = 'python'
# make pythOn out of the word

# %%
word.index("o")
# Out:
# 4

# %%
for i in range(len(word)):
    if word[i]=="o":
        first = word[:i]
        second = word[i+1:]
        letter_to_cap = word[i].upper()
        result = f"{first}{letter_to_cap}{second}"
print(first)
print(second)
print(result)
# Out:
# pyth
# n
# pythOn

# %%
for index, letter in enumerate(word):
    if letter=="o":
        print(index, letter)
# Out:
# 4 o

# %%
word='python'
d = word.find('o')
word[0:d] + word[d:].capitalize()
# Out:
# 'pythOn'

# %%
f = lambda a,b : a + b

# %%
f(5,6)
# Out:
# 11
